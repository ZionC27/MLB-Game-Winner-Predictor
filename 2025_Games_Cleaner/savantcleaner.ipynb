# %%
import pandas as pd

df = pd.read_csv('savant_data.csv')
df2 = pd.read_csv('savant_data (2).csv')
df

# %%
df = pd.concat([df, df2], ignore_index=True)
df

# %%
columns_to_keep = [
    "player_id", "player_name", "xwoba", "k_percent", "bb_percent",
    "hardhit_percent", "barrels_per_bbe_percent", "velocity", "spin_rate", "swing_miss_percent"
]
df_filtered = df[columns_to_keep]
df_filtered

# %%
df_filtered.to_csv('pitch_cleaned_2025.csv', index=False)

# %%
import pandas as pd

df1 = pd.read_csv('savant_data (1).csv')
df2 = pd.read_csv('savant_data (3).csv')
df = pd.concat([df1, df2], ignore_index=True)

# %%
columns_selected = [
    "player_id", "player_name", "xwoba", "k_percent", "bb_percent",
    "barrels_per_pa_percent", "hardhit_percent", "launch_speed", "bat_speed"
]
df_selected = df[columns_selected]
df_selected
# Out:
#     player_id          player_name  xwoba  k_percent  bb_percent  \
# 0      660271       Ohtani, Shohei  0.447       24.9        11.1
# 1      571970           Muncy, Max  0.371       24.2        15.2
# 2      605141        Betts, Mookie  0.355        9.0        10.5
# 3      681624          Pages, Andy  0.345       18.4         5.1
# 4      624424    Conforto, Michael  0.336       25.8        14.0
# 5      669257          Smith, Will  0.393       17.4        15.0
# 6      518692     Freeman, Freddie  0.392       20.3         8.2
# 7      606192   Hernández, Teoscar  0.352       22.4         3.7
# 8      669242         Edman, Tommy  0.341       17.4         3.6
# 9      571771   Hernández, Enrique  0.317       26.2         9.0
# 10     500743        Rojas, Miguel  0.246       14.4         4.1
# 11     808975        Kim, Hyeseong  0.329       21.9         4.7
# 12     605131       Barnes, Austin  0.244       31.8         2.3
# ...

# %%
df_selected.to_csv('bat_cleaned_2025.csv', index=False)
